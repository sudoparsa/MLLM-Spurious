# %%
import sys
sys.path.append('/cmlscratch/snawathe/MLLM-Spurious/pipeline')

# %%
import pandas as pd
import json
from aggregate_results import get_results_df, compute_single_score, compute_scores
from image_mask_datasets import CityscapesImageMaskDataset

# %%
def get_cityscape_label_name(cityscape_label_id: int) -> str:
	return list(filter(lambda lab: lab.id == cityscape_label_id, CityscapesImageMaskDataset.labels))[0].name

# %%
def compute_cityscape_scores(cityscape_label_idx: int) -> pd.DataFrame:
	print(get_cityscape_label_name(cityscape_label_idx))
	return compute_scores(f'cityscape-{cityscape_label_idx}', 'qwen', 'owl', f'cityscape-{cityscape_label_idx}.txt', include_random=True)

# %%
compute_cityscape_scores(20)
# Out:
# traffic sign
#    spur_feature_name  hallucination_score  score_natural_unbiased  \
# 4          road sign             0.200000                0.340000
# 18          bus stop             0.180000                0.173333
# 15        signal box             0.166667                0.106667
# 14              sign             0.133333                0.240000
# 10      intersection             0.130000                0.133333
# 12     parking meter             0.120000                0.093333
# 5            bicycle             0.070000                0.053333
# 11              pole             0.063333                0.113333
# 17    sidewalk bench             0.063333                0.026667
# 3         pedestrian             0.063333                0.133333
# 2               tree             0.056667               -0.053333
# 19               car             0.053333                0.033333
# 0                sky             0.050000                0.006667
# ...

# %%
compute_cityscape_scores(26)
# Out:
# car
#    spur_feature_name  hallucination_score  score_natural_unbiased  \
# 10              tire             0.353333                0.473333
# 7            exhaust             0.243333                0.146667
# 17         headlight             0.190000                0.380000
# 2            license             0.153333                0.213333
# 27       parking lot             0.146667                0.166667
# 12            mirror             0.140000                0.053333
# 26            bumper             0.116667                0.133333
# 18            grille             0.106667                0.133333
# 9           seatbelt             0.100000               -0.026667
# 13          steering             0.083333                0.026667
# 4               road             0.076667                0.226667
# 29         dashboard             0.060000                0.053333
# 31     traffic light             0.060000                0.086667
# ...

# %%
compute_cityscape_scores(28)
# Out:
# bus
#    spur_feature_name  hallucination_score  score_natural_unbiased  \
# 3          passenger             0.083333                0.146667
# 9          crosswalk             0.063333                0.086667
# 20     advertisement             0.050000                0.140000
# 11           luggage             0.050000                0.140000
# 13          schedule             0.030000                0.080000
# 12        park bench             0.026667                0.033333
# 17          overpass             0.023333                0.006667
# 5           building             0.010000                0.040000
# 8      traffic signs             0.003333                0.006667
# 19            street             0.000000                0.000000
# 10     road markings            -0.003333               -0.006667
# 21    traffic lights            -0.003333               -0.006667
# 14             bench            -0.003333               -0.006667
# ...

# %%
compute_cityscape_scores(32)
# Out:
# motorcycle
#    spur_feature_name  hallucination_score  score_natural_unbiased  \
# 26            bikers             0.240000                0.480000
# 14            helmet             0.203333                0.446667
# 24         kickstand             0.110000                0.200000
# 27            fender             0.106667                0.233333
# 31   random ordering             0.090000                0.160000
# 20          pavement             0.033333                0.026667
# 6            exhaust             0.033333                0.106667
# 16         headlight             0.023333                0.046667
# 17      traffic sign             0.010000                0.060000
# 25        bike stand            -0.006667               -0.033333
# 4               tree            -0.006667                0.006667
# 23      fuel station            -0.010000                0.020000
# 30             chain            -0.016667               -0.013333
# ...
