# %%
import pandas as pd
import pickle as pkl
from env_vars import HARDIMAGENET_PATH
from aggregate_results import get_results_df, compute_single_score, compute_scores

# %%
with open(f'{HARDIMAGENET_PATH}/meta/paths_by_rank.pkl', 'rb') as f:
	paths_by_rank = pkl.load(f)
with open(f'{HARDIMAGENET_PATH}/meta/imagenet_classnames.pkl', 'rb') as f:
	imagenet_classnames = pkl.load(f)
with open(f'{HARDIMAGENET_PATH}/meta/hard_imagenet_idx.pkl', 'rb') as f:
	hard_imagenet_idx = pkl.load(f)

# %%
df = compute_scores('hardimagenet-0', 'qwen', 'owl', 'hardimagenet-0.txt', include_random=True)
sorted_idxs = list(range(len(paths_by_rank[hard_imagenet_idx[0]])))
df = pd.concat([df, pd.DataFrame([compute_single_score(get_results_df('hardimagenet-0', 'qwen'), 'hardimagenet', sorted_idxs)])])
df.sort_values(by='hallucination_score', inplace=True, ascending=False)
df
# Out:
#    spur_feature_name  hallucination_score  score_natural_unbiased  \
# 24              sign             0.173333                0.020000
# 17               ice             0.173333                0.000000
# 19            sunset             0.166667                0.000000
# 5               wind             0.163333                0.000000
# 12              food             0.160000                0.000000
# 2              cloud             0.146667               -0.020000
# 0       hardimagenet             0.143333                0.000000
# 15          mountain             0.143333                0.000000
# 0             driver             0.136667                0.000000
# 13        binoculars             0.136667               -0.020000
# 10           harness             0.130000                0.000000
# 4               hill             0.130000                0.000000
# 3              water             0.123333               -0.020000
# ...
